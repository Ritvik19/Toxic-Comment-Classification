# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from tqdm.auto import tqdm, trange
tqdm.pandas()
# Out:
# D:\Users\Ritvik\Anaconda3\envs\datascience\lib\site-packages\tqdm\std.py:648: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %%
data = pd.read_csv('data.csv')
print(data.shape)
data.head()
# Out:
# (223549, 10)
#                                         comment_text  identity_hate  insult  \
# 0  Explanation\nWhy the edits made under my usern...              0       0
# 1  D'aww! He matches this background colour I'm s...              0       0
# 2  Hey man, I'm really not trying to edit war. It...              0       0
# 3  "\nMore\nI can't make any real suggestions on ...              0       0
# 4  You, sir, are my hero. Any chance you remember...              0       0
#
#    obscene  severe_toxic  threat  toxic  positive  len  \
# 0        0             0       0      0         1   43
# 1        0             0       0      0         1   17
# 2        0             0       0      0         1   42
# 3        0             0       0      0         1  113
# 4        0             0       0      0         1   13
#
#                                           clean_text
# 0  explanation edits username hardcore metallica ...
# 1  aww matches background colour seemingly stuck ...
# 2  hey man really trying edit war guy constantly ...
# 3  make real suggestions improvement wondered sec...
# 4                      sir hero chance remember page

# %%
data.dropna(inplace=True)
data.reset_index(drop=True, inplace=True)
print(data.shape)
# Out:
# (223162, 10)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.dummy import DummyClassifier

# %%
labels= ['identity_hate', 'insult', 'obscene', 'severe_toxic', 'threat', 'toxic']

# %%
vectorizer = TfidfVectorizer()
vects = vectorizer.fit_transform(data['clean_text'])

target = data[labels].values

# %%
print('X shape', vects.shape)
print('Y shape', target.shape)
# Out:
# X shape (223162, 237834)
# Y shape (223162, 6)

# %%
from utils.ml import *

# %%
model = DummyClassifier(strategy='stratified', random_state=None)
performance, cm, model = train_model_one_vs_rest(model, vects, target, labels)
print('Mean Loss', round(np.mean(performance['loss']), 4), '+-', round(np.std(performance['loss']), 4))
# Out:
# Mean Loss 0.0691 +- 0.001
